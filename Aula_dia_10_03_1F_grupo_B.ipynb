# %% [markdown]
# <a href="https://colab.research.google.com/github/lloris318-lorena/PA--1-F---grupo-B/blob/main/Aula_dia_10_03_1F_grupo_B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#entrada

lado1 = float (input("digite o comprimento:"))
lado2 = float (input("digite a altura:"))

#processamento

area = lado1 * lado2

#saida

print (f"o total da área é :{area} metros quadrados")
# Out:
# digite o comprimento:3
# digite a altura:3
# o total da área é :9.0 metros quadrados

# %% [markdown]
# Escrever um programa que calcula o dobro de um numero.

# %%
#entrada
num1 = int (input("digite um numero:"))

#processamento

dobro = num1 * 2

#saida

print(f"o dobro do {num1} é: {dobro}")
# Out:
# digite um numero:4
# o dobro do 4 é: 8

# %% [markdown]
# Fazer um programa que o usuario ira entrar com 04 notas, vamos calcular a média e mostrar ao usuario a media

# %%
#entrada

N1 = float (input("digite sua primeira nota"))
N2 = float (input("digite sua segunda nota"))
N3 = float (input("digite sua terceira nota"))
N4 = float (input("digite sua quarta nota"))

#processamento

soma = N1+N2+N3+N4
media = (soma) /4

#saida

print(f"sua media final:{media}")
# Out:
# digite sua primeira nota2
# digite sua segunda nota2
# digite sua terceira nota2
# digite sua quarta nota2
# sua media final:2.0

# %% [markdown]
# Fazer um cadrastro simples de usuario.
#
# objetivo: Usar string (str)
#
# Logica
#
# Entrada: nome e idade Processamento : armazenar Saida: exibir uma mensagem (ola(nome), voce tem x anos de idade

# %%
#entrada

nome = str(input("digite seu nome:"))
idade = int(input("digte sua idade:"))

#processamento
usuário = {nome},{idade}

#saida
print(f"Olá {nome}, você tem {idade} anos de idade." )
# Out:
# digite seu nome:lorena
# digte sua idade:15
# Olá lorena, você tem 15 anos de idade.
