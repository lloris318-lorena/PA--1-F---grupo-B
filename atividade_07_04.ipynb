# %% [markdown]
# <a href="https://colab.research.google.com/github/lloris318-lorena/PA--1-F---grupo-B/blob/main/atividade_07_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Questão 1

#entrada

idade = int (input("digite sua idade"))

#processamento

if idade <= 17:
 print (f"você é menor de idade. ")

elif idade >= 18 and idade <= 59:
 print (f"Você é adulto.")

else:
 print (f"você é idoso.")
# Out:
# digite sua idade15
# você é menor de idade.

# %%
#Questão 2 ?

#entrada

compra = float (input("digite o valor da sua compra:"))
desconto =
#processamento

if compra <= 100:
  print (f"sem desconto")

elif compra >= 101 or compra <= 500:
  print (f"")

# %%
#Questão 3

#entrada

valor1 = float (input("digite um valor."))
valor2 = float (input("digite um segundo valor."))
valor3 = float (input("digite um terceiro valor."))

soma = valor1 + valor2

#processamento

if soma >= valor3:
 print(f"este triangulo é valido.")

else:
  print (f"este triangulo não é valido")
# Out:
# digite um valor.1
# digite um segundo valor.1
# digite um terceiro valor.3
# este triangulo não é valido

# %%
#Questão 4

#entrada

energia = int (input("digite a energia"))

#processamento e saida

if energia <= 0:
 print (f"Morto")

elif energia >= 1 and energia <= 30:
  print (f"Crítico")

elif energia >= 31 and energia <= 70:
  print (f"Normal")

else:
  print (f"Saudável")
# Out:
# digite a energia71
# Saudável

# %%
#Questão 5

#entrada

media = float (input("digite sua media"))

#processamento e saida

if media >= 7:
  print (f"Aprovado")

elif media >= 5 and media <= 6.9:
  print ("recuperação")

else:
  print (f"Reprovado")
# Out:
# digite sua media4
# Reprovado

# %%
#Questão 6 ?

#entrada
