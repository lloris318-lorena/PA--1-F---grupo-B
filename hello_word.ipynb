# %% [markdown]
# <a href="https://colab.research.google.com/github/lloris318-lorena/PA--1-F---grupo-B/blob/main/hello_word.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello word")
# Out:
# hello word
